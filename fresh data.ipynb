# %%
import pandas as pd

# %%
data1 = pd.read_csv("abc data 1.csv")
data2 = pd.read_csv("abcd data 2.csv")
data3 = pd.read_csv("abcde data 3.csv")

# %%
print("Data1:", data1.shape)
print("Data2:", data2.shape)
print("Data3:", data3.shape)
# Out:
# Data1: (610, 10)
# Data2: (610, 8)
# Data3: (390, 16)

# %%
data1 = pd.read_csv("abc data 1.csv")
data2 = pd.read_csv("abcd data 2.csv")
data3 = pd.read_csv("abcde data 3.csv")

# %%
merged_df1_2 = pd.concat([data1, data2], ignore_index=True)
merged_df1_2.shape  # Check dimensions
# Out:
# (1220, 17)

# %%
final_df = pd.concat([merged_df1_2, data3], ignore_index=True)
final_df.shape  # Final shape of merged data
# Out:
# (1610, 17)

# %%
final_df.to_csv("final_cleaned_dataset.csv", index=False)
print("✅ Final dataset saved as: final_cleaned_dataset.csv")
# Out:
# ✅ Final dataset saved as: final_cleaned_dataset.csv

# %%
import pandas as pd

# %%
# Load the cleaned dataset created earlier
final_cleaned = pd.read_csv("final_cleaned_dataset.csv")

# Load the third dataset
abcde = pd.read_csv("abcde data 3.csv")

# %%
final_merged = pd.concat([final_cleaned, abcde], ignore_index=True)

# %%
final_merged.head()
# Out:
#    instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
#
#    temp  Unnamed: 0  atemp  hum  windspeed  casual  registered  cnt
# 0  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 1  0.22         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 2  0.22         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 3  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 4  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN

# %%
final_merged.info()
final_merged.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     2000 non-null   int64
#  1   dteday      1390 non-null   object
#  2   season      1390 non-null   float64
#  3   yr          1390 non-null   float64
#  4   mnth        1390 non-null   float64
#  5   hr          1390 non-null   float64
#  6   holiday     1390 non-null   object
#  7   weekday     1390 non-null   float64
#  8   weathersit  1390 non-null   float64
#  9   temp        1390 non-null   float64
#  10  Unnamed: 0  610 non-null    float64
#  11  atemp       1379 non-null   float64
#  12  hum         1390 non-null   float64
#  13  windspeed   1390 non-null   float64
#  14  casual      1390 non-null   float64
#  15  registered  1390 non-null   float64
#  16  cnt         1390 non-null   float64
# dtypes: float64(14), int64(1), object(2)
# memory usage: 265.8+ KB
# ...

# %%
final_merged.to_csv("final_merged_dataset.csv", index=False)

# %%
final_df.isnull().sum()
#finding Missing Values
# Out:
# instant          0
# dteday         610
# season         610
# yr             610
# mnth           610
# hr             610
# holiday        610
# weekday        610
# weathersit     610
# temp           610
# Unnamed: 0    1000
# atemp          621
# hum            610
# windspeed      610
# casual         610
# registered     610
# cnt            610
# dtype: int64

# %%
import pandas as pd

# Replace the path with your actual file path if different
final_df = pd.read_csv("final_cleaned_dataset.csv")
final_df.head()
# Out:
#    instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
#
#    temp  Unnamed: 0  atemp  hum  windspeed  casual  registered  cnt
# 0  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 1  0.22         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 2  0.22         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 3  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 4  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN

# %%
# Load the Cleaned Dataset

# %%
import pandas as pd

# Replace the path with your actual file path if different
final_df = pd.read_csv("final_cleaned_dataset.csv")
final_df.head()
# Out:
#    instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
#
#    temp  Unnamed: 0  atemp  hum  windspeed  casual  registered  cnt
# 0  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 1  0.22         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 2  0.22         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 3  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN
# 4  0.24         NaN    NaN  NaN        NaN     NaN         NaN  NaN

# %%
#Check for Missing Values

# %%
final_df.isnull().sum()
# Out:
# instant          0
# dteday         610
# season         610
# yr             610
# mnth           610
# hr             610
# holiday        610
# weekday        610
# weathersit     610
# temp           610
# Unnamed: 0    1000
# atemp          621
# hum            610
# windspeed      610
# casual         610
# registered     610
# cnt            610
# dtype: int64

# %%
#Describe the Dataset

# %%
final_df.describe()
# Out:
#            instant  season      yr         mnth           hr      weekday  \
# count  1610.000000  1000.0  1000.0  1000.000000  1000.000000  1000.000000
# mean    426.618012     1.0     0.0     1.312000    11.753000     2.982000
# std     269.261437     0.0     0.0     0.463542     6.899101     2.091423
# min       1.000000     1.0     0.0     1.000000     0.000000     0.000000
# 25%     202.000000     1.0     0.0     1.000000     6.000000     1.000000
# 50%     403.000000     1.0     0.0     1.000000    12.000000     3.000000
# 75%     604.000000     1.0     0.0     2.000000    18.000000     5.000000
# max    1000.000000     1.0     0.0     2.000000    23.000000     6.000000
#
#         weathersit         temp  Unnamed: 0       atemp          hum  \
# count  1000.000000  1000.000000  610.000000  989.000000  1000.000000
# mean      1.480000     0.205900  304.500000    0.211958     0.582480
# std       0.651171     0.078977  176.236111    0.076703     0.187977
# ...

# %%
# Skewness and Kurtosis

# %%
# Skewness: Measures asymmetry
print("Skewness:")
print(final_df.skew(numeric_only=True))

# Kurtosis: Measures peakedness
print("\nKurtosis:")
print(final_df.kurtosis(numeric_only=True))
# Out:
# Skewness:
# instant       0.347991
# season        0.000000
# yr            0.000000
# mnth          0.812772
# hr           -0.063524
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# Unnamed: 0    0.000000
# atemp         0.428564
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64
#
# Kurtosis:
# instant       -0.856255
# season         0.000000
# yr             0.000000
# mnth          -1.342090
# hr            -1.169998
# weekday       -1.346819
# weathersit     0.034960
# temp           0.775061
# Unnamed: 0    -1.200000
# atemp          0.670837
# hum           -0.723123
# windspeed     -0.209853
# casual        15.097740
# registered     1.642506
# cnt            1.026661
# dtype: float64

# %%
##Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(final_df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Datatypes and non-null counts
df.info()

df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1610 non-null   int64
#  1   dteday      1000 non-null   object
#  2   season      1610 non-null   float64
#  3   yr          1610 non-null   float64
#  4   mnth        1610 non-null   float64
#  5   hr          1610 non-null   float64
#  6   holiday     1000 non-null   object
#  7   weekday     1610 non-null   float64
#  8   weathersit  1610 non-null   float64
#  9   temp        1610 non-null   float64
#  10  Unnamed: 0  1610 non-null   float64
#  11  atemp       1610 non-null   float64
#  12  hum         1610 non-null   float64
#  13  windspeed   1610 non-null   float64
#  14  casual      1610 non-null   float64
#  15  registered  1610 non-null   float64
#  16  cnt         1610 non-null   float64
# dtypes: float64(14), int64(1), object(2)
# memory usage: 214.0+ KB
# ...

# %%
# Check missing values
df.isnull().sum()
# df['column_name'].fillna(value, inplace=True)
# df.dropna(inplace=True)
# Out:
# instant         0
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday       610
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0      0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
#Correlation Matrix & Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Mean, median, mode of numerical columns
df.mean(numeric_only=True)
df.median(numeric_only=True)
df.mode(numeric_only=True).head(1)
# Out:
#    instant  season   yr  mnth         hr   weekday  weathersit      temp  \
# 0        1     1.0  0.0   1.0  11.795082  2.977049    1.477049  0.196885
#
#    Unnamed: 0     atemp       hum  windspeed    casual  registered        cnt
# 0       304.5  0.199935  0.562475   0.204851  4.501639   51.068852  55.570492

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your cleaned dataset
df = pd.read_csv('final_cleaned_data.csv')

# Distribution Plots for Numerical Columns
numerical_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(15, 12))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# Boxplots for Outlier Detection
plt.figure(figsize=(15, 12))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 13
#      11 plt.figure(figsize=(15, 12))
#      12 for i, col in enumerate(numerical_cols, 1):
# ---> 13     plt.subplot(3, 3, i)
#      14     sns.histplot(df[col], kde=True, color='skyblue')
#      15     plt.title(f'Distribution of {col}')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
# ...

# %%
# Analyze skewness of numeric columns
skewness = df[numerical_cols].skew()
print("Skewness of Numeric Columns:")
print(skewness)
# Out:
# Skewness of Numeric Columns:
# instant       0.347991
# season        0.000000
# yr            0.000000
# mnth          1.550841
# hr           -0.089364
# weekday       0.031223
# weathersit    1.330587
# temp          0.853287
# Unnamed: 0    0.000000
# atemp         0.766863
# hum           0.703069
# windspeed     0.437587
# casual        4.401228
# registered    1.711920
# cnt           1.517703
# dtype: float64

# %%
# Mean
mean_values = df[numerical_cols].mean()
print("\nMean:\n", mean_values)

# Median
median_values = df[numerical_cols].median()
print("\nMedian:\n", median_values)

# Mode
mode_values = df[numerical_cols].mode().iloc[0]  # Take first mode value
print("\nMode:\n", mode_values)
# Out:
# Mean:
#  instant       426.618012
# season          1.000000
# yr              0.000000
# mnth            1.193789
# hr             11.768944
# weekday         2.980124
# weathersit      1.478882
# temp            0.202484
# Unnamed: 0    304.500000
# atemp           0.207320
# hum             0.574901
# windspeed       0.198690
# casual          4.762112
# registered     52.506211
# cnt            57.268323
# dtype: float64
#
# Median:
#  instant       403.000000
# season          1.000000
# yr              0.000000
# mnth            1.000000
# hr             11.795082
# weekday         2.977049
# weathersit      1.477049
# temp            0.196885
# Unnamed: 0    304.500000
# atemp           0.199935
# hum             0.562475
# windspeed       0.204851
# casual          4.501639
# registered     51.068852
# cnt            55.570492
# dtype: float64
#
# Mode:
#  instant         1.000000
# season          1.000000
# yr              0.000000
# mnth            1.000000
# ...

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'Unnamed: 0', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
for col in df.columns:
    print(col)
# Out:
# instant
# dteday
# season
# yr
# mnth
# hr
# holiday
# weekday
# weathersit
# temp
# Unnamed: 0
# atemp
# hum
# windspeed
# casual
# registered
# cnt

# %%
print(df.columns)
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'Unnamed: 0', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
print("Column Names:\n", df.columns.tolist())
# Out:
# Column Names:
#  ['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp', 'unnamed: 0', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %%
['ID', ' Years_of_Experience', 'CTC_LPA', 'Department']
# Out:
# ['ID', ' Years_of_Experience', 'CTC_LPA', 'Department']

# %%
print(df.columns.tolist())
# Out:
# ['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp', 'unnamed: 0', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %%
['Years_of_Experience', 'CTC_LPA', 'Department', ...]
# Out:
# ['Years_of_Experience', 'CTC_LPA', 'Department', Ellipsis]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='temp', y='cnt', color='blue')
plt.title("Scatter Plot: Temperature vs Ride Count")
plt.xlabel("Temperature (Normalized)")
plt.ylabel("Total Ride Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='temp', y='cnt', color='blue')
plt.title("Scatter Plot: Temperature vs Ride Count")
plt.xlabel("Temperature (Normalized)")
plt.ylabel("Total Ride Count")
plt.show()

# %%
sns.pairplot(df[['temp', 'atemp', 'hum', 'windspeed', 'cnt']])
plt.show()

# %%
sns.boxplot(data=df, x='season', y='cnt')
plt.title("Ride Count by Season")
plt.xlabel("Season")
plt.ylabel("Total Ride Count")
plt.show()

# %%
print("Missing values:\n", df.isnull().sum())
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Missing values:
#  instant         0
# dteday        610
# season          0
# yr              0
# mnth            0
# hr              0
# holiday       610
# weekday         0
# weathersit      0
# temp            0
# unnamed: 0      0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64
#
# Duplicate rows: 0

# %%
print(df.describe())
# Out:
#            instant  season      yr         mnth           hr      weekday  \
# count  1610.000000  1610.0  1610.0  1610.000000  1610.000000  1610.000000
# mean    426.618012     1.0     0.0     1.193789    11.768944     2.980124
# std     269.261437     0.0     0.0     0.395388     5.436261     1.647961
# min       1.000000     1.0     0.0     1.000000     0.000000     0.000000
# 25%     202.000000     1.0     0.0     1.000000    10.000000     2.000000
# 50%     403.000000     1.0     0.0     1.000000    11.795082     2.977049
# 75%     604.000000     1.0     0.0     1.000000    14.000000     4.000000
# max    1000.000000     1.0     0.0     2.000000    23.000000     6.000000
#
#         weathersit         temp   unnamed: 0        atemp          hum  \
# count  1610.000000  1610.000000  1610.000000  1610.000000  1610.000000
# mean      1.478882     0.202484   304.500000     0.207320     0.574901
# std       0.513100     0.062385   108.424025     0.060390     0.148436
# ...

# %%
sns.histplot(df['cnt'], kde=True)
plt.title("Distribution of Total Ride Count")
plt.xlabel("Ride Count")
plt.show()

# %%
sns.histplot(df['cnt'], kde=True)
plt.title("Distribution of Total Ride Count")
plt.xlabel("Ride Count")
plt.show()
